# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("economic_index.csv")
df.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
df.describe()
# Out:
#        Unnamed: 0         year      month  interest_rate  unemployment_rate  \
# count   24.000000    24.000000  24.000000      24.000000           24.00000
# mean    11.500000  2016.500000   6.500000       2.072917            5.77500
# std      7.071068     0.510754   3.526299       0.349527            0.33002
# min      0.000000  2016.000000   1.000000       1.750000            5.30000
# 25%      5.750000  2016.000000   3.750000       1.750000            5.50000
# 50%     11.500000  2016.500000   6.500000       2.000000            5.85000
# 75%     17.250000  2017.000000   9.250000       2.500000            6.10000
# max     23.000000  2017.000000  12.000000       2.750000            6.20000
#
#        index_price
# count    24.000000
# mean   1070.083333
# std     210.735341
# min     704.000000
# 25%     928.250000
# 50%    1061.000000
# 75%    1239.000000
# max    1464.000000

# %%
df.tail()
# Out:
#     Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 19          19  2016      5           1.75                6.1          866
# 20          20  2016      4           1.75                5.9          876
# 21          21  2016      3           1.75                6.2          822
# 22          22  2016      2           1.75                6.2          704
# 23          23  2016      1           1.75                6.1          719

# %%
### drop the extra/unnecessary column
df.drop(columns=["Unnamed: 0","year","month"],inplace=True)

# %%
df.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
df.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
### visulization
sns.pairplot(df)

# %%
df.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
plt.scatter(df['interest_rate'],df['unemployment_rate'],color='r')
plt.xlabel("Interest Rate")
plt.ylabel("Unemployment Rate")
# Out:
# Text(0, 0.5, 'Unemployment Rate')

# %%
###independent and dependent feature
X = df[['interest_rate','unemployment_rate']]
y= df["index_price"]

# %%
### another method to write independent feature
# X = df.iloc[:,:-1]
# y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    interest_rate  unemployment_rate
# 0           2.75                5.3
# 1           2.50                5.3
# 2           2.50                5.3
# 3           2.50                5.3
# 4           2.50                5.4

# %%
y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     822
# 22     704
# 23     719
# Name: index_price, dtype: int64

# %%
## train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test  = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
sns.regplot(x=df['interest_rate'],y=df['index_price'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(data=df , x="interest_rate",y="unemployment_rate")
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
### cross validation
from sklearn.model_selection import cross_val_score
validation_score = cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',cv=3)

# %%
np.mean(validation_score)
# Out:
# np.float64(-5914.828180162388)

# %%
## prediction 
y_pred = regression.predict(X_test) 
y_pred
# Out:
# array([1204.22770398,  821.65051903, 1406.51300368,  857.70889608,
#         994.90992298, 1168.16932693])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
rmse= np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 5793.762887712569
# 59.935781523235484
# 76.11677139574805

# %%
### r square
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.8278978091457145

# %%
### assumptions
plt.scatter(y_test,y_pred)

# %%
residuals = y_test-y_pred
print(residuals)
# Out:
# 8     -45.227704
# 16    149.349481
# 0      57.486996
# 18     26.291104
# 11     80.090077
# 9      -1.169327
# Name: index_price, dtype: float64

# %%
##plot the residuals
sns.displot(residuals,kind='kde')

# %%
### scaterr plot wrt to prediction and residuals
plt.scatter(y_pred,residuals)

# %%
###OLS Linear regression
import statsmodels.api as sm
model = sm.OLS(y_train,X_train).fit()
prediction = model.predict(X_test)
print(prediction)
# Out:
# [ 150.78325954 -231.79392541  353.06855924 -195.73554836  -58.53452146
#   114.72488249]

# %%
### prediction for new data
regression.predict(scaler.transform([[2,6]]))
# Out:
# c:\Users\VICTUS\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([958.85154593])

# %%
### to remove the above warning use this method (ocrrect way)

new_data = pd.DataFrame(
    [[2, 6]],
    columns=["interest_rate", "unemployment_rate"]
)

new_data_scaled = scaler.transform(new_data)

prediction = regression.predict(new_data_scaled)

print(prediction)
# Out:
# [958.85154593]
